# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import binascii

# %%
df = pd.read_csv(r'C:\Users\adams\OneDrive\Documents\Code\northsec\Data Analysis Track\part 1 - find corruption\national_citizen_database.csv')
df.head()
# Out:
#        name  last_name  coord_x  ...  grad_year  parent_donations_k  final_grade
# 0   vernell     benton      148  ...       1981           50.415308    81.982484
# 1   matthew  mccormick       30  ...       2007           50.493455    82.541471
# 2      lulu    kennedy        5  ...       1980           49.783407    83.879590
# 3     hyrum   richmond      129  ...       1999           49.770613    83.075805
# 4  isabella       mayo       49  ...       2008           50.191517    82.601419
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4989999 entries, 0 to 4989998
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   name                   object
#  1   last_name              object
#  2   coord_x                int64
#  3   coord_y                int64
#  4   group                  int64
#  5   docile                 int64
#  6   voice_pitch            float64
#  7   facial_ratio           float64
#  8   retina_r               float64
#  9   retina_g               float64
#  10  retina_b               float64
#  11  humidity_index         float64
#  12  parent_worth           int64
#  13  social_index           float64
#  14  consumer_score         float64
#  15  citizen_quality_score  float64
#  16  prob_failure           float64
#  17  z_index                float64
#  18  school_id              object
#  19  student_id             object
#  20  genre_id               int64
# ...

# %%
df.describe()
# Out:
#             coord_x       coord_y         group        docile   voice_pitch  \
# count  4.989999e+06  4.989999e+06  4.989999e+06  4.989999e+06  4.989999e+06
# mean   8.338546e+01 -1.212412e+02  1.701516e+01  8.959930e-01  1.922947e-01
# std    5.127735e+01  7.690174e+01  1.013515e+01  3.052697e-01  2.113961e-01
# min    0.000000e+00 -2.510000e+02  0.000000e+00  0.000000e+00 -1.000000e+00
# 25%    3.600000e+01 -1.890000e+02  9.000000e+00  1.000000e+00  9.124322e-02
# 50%    8.200000e+01 -1.210000e+02  1.600000e+01  1.000000e+00  2.180383e-01
# 75%    1.270000e+02 -4.700000e+01  2.600000e+01  1.000000e+00  3.310624e-01
# max    2.210000e+02  0.000000e+00  3.500000e+01  1.000000e+00  1.000000e+00
#
#        facial_ratio      retina_r      retina_g      retina_b  humidity_index  \
# count  4.989999e+06  4.989999e+06  4.989999e+06  4.989999e+06    4.989999e+06
# mean   5.546983e-01  4.707836e-01  5.217570e-01  4.781689e-01    5.180587e-01
# ...

# %%
df.corr()
# Out:
#                         coord_x   coord_y     group    docile  voice_pitch  \
# coord_x                1.000000 -0.018591  0.069763  0.000313     0.000811
# coord_y               -0.018591  1.000000 -0.037122  0.000523    -0.000212
# group                  0.069763 -0.037122  1.000000  0.000062     0.000092
# docile                 0.000313  0.000523  0.000062  1.000000     0.651775
# voice_pitch            0.000811 -0.000212  0.000092  0.651775     1.000000
# facial_ratio          -0.000111  0.000315 -0.000222  0.564864     0.080288
# retina_r              -0.000006 -0.001046  0.000231 -0.619276     0.030003
# retina_g              -0.000669 -0.000486  0.000514 -0.000386    -0.000423
# retina_b              -0.000099 -0.000982  0.000111 -0.406707     0.237358
# humidity_index        -0.001209 -0.000462 -0.000468 -0.000298    -0.209093
# parent_worth           0.000510  0.000703 -0.000019  0.000064    -0.112276
# ...

# %%
aggregated = df.groupby('school_id')[['parent_donations_k', 'final_grade']].corr().iloc[0::2][['final_grade']]

# %%
aggregated.sort_values('final_grade')
# Out:
#                                                      final_grade
# school_id
# 28379cee9231d5860570ba5bd9e10a0b parent_donations_k    -0.444672
# aa0d4946776a4303a84c596615579a01 parent_donations_k    -0.435801
# 23c09946c5a7e0ba442b92cc5c4d7d0d parent_donations_k    -0.435265
# d17698485025674a2eb98cb3012186dc parent_donations_k    -0.434129
# bb6d2ff4ac4dd7656ff3f88c18bf9a49 parent_donations_k    -0.433836
# ...                                                          ...
# e0361ac9d3a3e273f2c1ba00234115f1 parent_donations_k     0.445959
# 5d43edc77f50aa6e49f68ffd67e4306e parent_donations_k     0.448191
# a22934a29447d8ac4cd111a42a1c91ea parent_donations_k     0.452713
# cbde160295a1062e08f042df844ccfc4 parent_donations_k     0.456563
# d5157c2992a5bde028a8bf1dc96384ad parent_donations_k     0.813944
#
# [5000 rows x 1 columns]

# %%
severity_high = df.loc[df['school_id'] == 'd5157c2992a5bde028a8bf1dc96384ad']
severity_high.head()
# Out:
#            name   last_name  coord_x  coord_y  group  docile  voice_pitch  \
# 3980    indiana     harrell       24      -19     26       0     0.361894
# 4823       emil      hanson        2     -102      1       0    -0.451374
# 4941   chauncey      garner      213     -240     34       1     0.524300
# 12615     hilda     jimenez       50      -91      9       1     0.272742
# 14680   rosalie  villanueva        6     -185     10       1     0.314962
#
#        facial_ratio  retina_r  retina_g  ...  consumer_score  \
# 3980       0.508624  0.500839  0.416041  ...       65.407455
# 4823       0.423228  0.512962  0.617496  ...       30.088449
# 4941       0.562706  0.595912  0.358051  ...       70.244927
# 12615      0.538801  0.522089  0.559372  ...       53.342156
# 14680      0.614563  0.527417  0.440366  ...       58.188111
#
#        citizen_quality_score  prob_failure    z_index  \
# 3980               50.083911     30.133490  68.094716
# ...

# %%
lizes = severity_high[severity_high['name'].str.contains('liz', na=False)]
lizes.head()
# Out:
#               name last_name  coord_x  coord_y  group  docile  voice_pitch  \
# 1365174  elizebeth   roberts       93     -122      5       1     0.226194
#
#          facial_ratio  retina_r  retina_g  ...  consumer_score  \
# 1365174       0.57847  0.482952  0.541366  ...       56.513322
#
#          citizen_quality_score  prob_failure    z_index  \
# 1365174              48.295186     55.264032  61.309701
#
#                                 school_id  \
# 1365174  d5157c2992a5bde028a8bf1dc96384ad
#
#                                    student_id  genre_id  grad_year  \
# 1365174  0aa3be34-36f1-4fcc-9e01-cbaeaa9f5709         2       2007
#
#         parent_donations_k final_grade
# 1365174           50.10844   83.292677
#
# [1 rows x 24 columns]

# %%
severity_high.corr()
# Out:
#                         coord_x   coord_y     group    docile  voice_pitch  \
# coord_x                1.000000 -0.024956  0.041935  0.039477     0.019404
# coord_y               -0.024956  1.000000 -0.073718 -0.067524    -0.038776
# group                  0.041935 -0.073718  1.000000  0.026341     0.044104
# docile                 0.039477 -0.067524  0.026341  1.000000     0.604571
# voice_pitch            0.019404 -0.038776  0.044104  0.604571     1.000000
# facial_ratio           0.017362 -0.010652  0.034258  0.590102     0.096779
# retina_r              -0.067591  0.038947 -0.018640 -0.599924     0.090091
# retina_g               0.022268 -0.011794  0.004030  0.044472     0.020761
# retina_b              -0.046858  0.018666 -0.018432 -0.441156     0.230963
# humidity_index        -0.037105  0.020311 -0.015993 -0.037082    -0.275875
# parent_worth           0.050111 -0.025865  0.021666  0.020936    -0.102186
# ...

# %%
severity_high.columns
# Out:
# Index(['name', 'last_name', 'coord_x', 'coord_y', 'group', 'docile',
#        'voice_pitch', 'facial_ratio', 'retina_r', 'retina_g', 'retina_b',
#        'humidity_index', 'parent_worth', 'social_index', 'consumer_score',
#        'citizen_quality_score', 'prob_failure', 'z_index', 'school_id',
#        'student_id', 'genre_id', 'grad_year', 'parent_donations_k',
#        'final_grade'],
#       dtype='object')

# %%
# Out:
# Empty DataFrame
# Columns: [name, last_name, coord_x, coord_y, group, docile, voice_pitch, facial_ratio, retina_r, retina_g, retina_b, humidity_index, parent_worth, social_index, consumer_score, citizen_quality_score, prob_failure, z_index, school_id, student_id, genre_id, grad_year, parent_donations_k, final_grade]
# Index: []
#
# [0 rows x 24 columns]
